# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_csv("laptops_train.csv")
test=pd.read_csv("laptops_test.csv")

# %%
test.head()
# Out:
#   Manufacturer                         Model Name            Category  \
# 0           HP  15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1         Asus                   Rog GL753VE-DS74              Gaming
# 2         Dell                      Inspiron 7579  2 in 1 Convertible
# 3      Toshiba                  Portege Z30-C-1CV            Notebook
# 4       Lenovo                  IdeaPad 320-15ABR            Notebook
#
#   Screen Size                                     Screen  \
# 0       15.6"                                   1366x768
# 1       17.3"                          Full HD 1920x1080
# 2       15.6"  IPS Panel Full HD / Touchscreen 1920x1080
# 3       13.3"                          Full HD 1920x1080
# 4       15.6"                          Full HD 1920x1080
#
#                            CPU   RAM               Storage  \
# 0   Intel Core i7 7500U 2.7GHz   6GB               1TB HDD
# 1  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# ...

# %%
train.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
test.head()
# Out:
#   Manufacturer                         Model Name            Category  \
# 0           HP  15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1         Asus                   Rog GL753VE-DS74              Gaming
# 2         Dell                      Inspiron 7579  2 in 1 Convertible
# 3      Toshiba                  Portege Z30-C-1CV            Notebook
# 4       Lenovo                  IdeaPad 320-15ABR            Notebook
#
#   Screen Size                                     Screen  \
# 0       15.6"                                   1366x768
# 1       17.3"                          Full HD 1920x1080
# 2       15.6"  IPS Panel Full HD / Touchscreen 1920x1080
# 3       13.3"                          Full HD 1920x1080
# 4       15.6"                          Full HD 1920x1080
#
#                            CPU   RAM               Storage  \
# 0   Intel Core i7 7500U 2.7GHz   6GB               1TB HDD
# 1  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              977 non-null    object
#  1   Model Name                977 non-null    object
#  2   Category                  977 non-null    object
#  3   Screen Size               977 non-null    object
#  4   Screen                    977 non-null    object
#  5   CPU                       977 non-null    object
#  6   RAM                       977 non-null    object
#  7    Storage                  977 non-null    object
#  8   GPU                       977 non-null    object
#  9   Operating System          977 non-null    object
#  10  Operating System Version  841 non-null    object
#  11  Weight                    977 non-null    object
#  12  Price                     977 non-null    float64
# dtypes: float64(1), object(12)
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              325 non-null    object
#  1   Model Name                325 non-null    object
#  2   Category                  325 non-null    object
#  3   Screen Size               325 non-null    object
#  4   Screen                    325 non-null    object
#  5   CPU                       325 non-null    object
#  6   RAM                       325 non-null    object
#  7    Storage                  325 non-null    object
#  8   GPU                       325 non-null    object
#  9   Operating System          325 non-null    object
#  10  Operating System Version  291 non-null    object
#  11  Weight                    325 non-null    object
#  12  Price                     325 non-null    float64
# dtypes: float64(1), object(12)
# ...

# %%
data=pd.concat([train,test],axis=0,ignore_index=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1302 non-null   object
#  1   Model Name                1302 non-null   object
#  2   Category                  1302 non-null   object
#  3   Screen Size               1302 non-null   object
#  4   Screen                    1302 non-null   object
#  5   CPU                       1302 non-null   object
#  6   RAM                       1302 non-null   object
#  7    Storage                  1302 non-null   object
#  8   GPU                       1302 non-null   object
#  9   Operating System          1302 non-null   object
#  10  Operating System Version  1132 non-null   object
#  11  Weight                    1302 non-null   object
#  12  Price                     1302 non-null   float64
# dtypes: float64(1), object(12)
# ...

# %%
plt.figure(figsize=(7,5))
sns.distplot(data["Price"])
# Out:
# C:\Users\nadee\AppData\Local\Temp\ipykernel_19360\3058530774.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Price"])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
feature_count=data["Operating System Version"].value_counts()

# %%
plt.figure(figsize=(7,5))
feature_count.plot(kind="bar")
plt.show()

# %%
data["Operating System"].value_counts()
# Out:
# Operating System
# Windows      1124
# No OS          66
# Linux          62
# Chrome OS      27
# macOS          13
# Mac OS          8
# Android         2
# Name: count, dtype: int64

# %%
null_count=data[data["Operating System Version"].isnull()]['Operating System'].value_counts()

# %%
plt.figure(figsize=(7,5))
null_count.plot(kind="bar")
plt.show()

# %%
unique_cat=data.groupby('Operating System')["Operating System Version"].nunique()

# %%
plt.figure(figsize=(7,5))
unique_cat.plot(kind="bar")
plt.show()

# %%
data.drop("Operating System Version",axis=1,inplace=True)

# %%
data.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS  1.37kg
# ...

# %%
man_name=data['Manufacturer'].value_counts()

# %%
plt.figure(figsize=(10, 6))
man_name.plot(kind='bar', color='skyblue')
plt.title('Distribution of Manufacturer')
plt.xlabel('Manufacturer')
plt.ylabel('Count')
plt.show()

# %%
Model_counts = data["Model Name"].value_counts()

# Plotting
plt.figure(figsize=(10, 4))
Model_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Categories in Feature')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.show()

# %%
Category_counts = data["Category"].value_counts()

# Plotting
plt.figure(figsize=(6, 4))
Category_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Categories in Feature')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.show()

# %%
Screen_size_counts = data["Screen Size"].value_counts()

# Plotting
plt.figure(figsize=(6, 4))
Screen_size_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Categories in Feature')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      1302 non-null   object
#  1   Model Name        1302 non-null   object
#  2   Category          1302 non-null   object
#  3   Screen Size       1302 non-null   object
#  4   Screen            1302 non-null   object
#  5   CPU               1302 non-null   object
#  6   RAM               1302 non-null   object
#  7    Storage          1302 non-null   object
#  8   GPU               1302 non-null   object
#  9   Operating System  1302 non-null   object
#  10  Weight            1302 non-null   object
#  11  Price             1302 non-null   float64
# dtypes: float64(1), object(11)
# memory usage: 122.2+ KB

# %%
data["Screen Size"]=data["Screen Size"].str.strip('"').astype(float)

# %%
data.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS  1.37kg
# ...

# %%
Screen_counts = data["Screen"].value_counts()

# Plotting
plt.figure(figsize=(6, 4))
Screen_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Categories in Feature')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.show()

# %%
data["Screen_resolution"]=data["Screen"].str.extract(r'(\d+x\d+)')

# %%
data.tail()
# Out:
#      Manufacturer                           Model Name            Category  \
# 1297       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1298       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1299       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1300           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1301         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       Screen Size                                      Screen  \
# 1297         14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1298         13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1299         14.0                                    1366x768
# 1300         15.6                                    1366x768
# 1301         15.6                                    1366x768
#
#                                        CPU   RAM             Storage  \
# ...

# %%
data['Display Type']=data['Screen'].str.replace(r'(\d+x\d+)','',regex=True)
data['Display Type']=data['Display Type'].str.replace(r'(Full HD|Ultra HD|4K Ultra HD|Quad HD|\+|/)','', regex=True)
data["Touchscreen"]=data["Display Type"].str.extract(r'(Touchscreen)')
data['Display Type']=data['Display Type'].str.replace(r'(Touchscreen)','',regex=True)
data["Touchscreen"]=data["Touchscreen"].replace(r'Touchscreen',1)
data["Touchscreen"]=data["Touchscreen"].replace(np.nan,0)

# %%
data['Display Type']=data['Display Type'].replace(r' ','',regex=True)
data['Display Type']=data['Display Type'].replace(r'^\s*$',np.nan,regex=True)

# %%
Screen_counts = data["Display Type"].value_counts()

# Plotting
plt.figure(figsize=(6, 4))
Screen_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Categories in Feature')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.show()

# %%
Screen_counts = data["Touchscreen"].value_counts()

# Plotting
plt.figure(figsize=(6, 4))
Screen_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Categories in Feature')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Manufacturer       1302 non-null   object
#  1   Model Name         1302 non-null   object
#  2   Category           1302 non-null   object
#  3   Screen Size        1302 non-null   float64
#  4   Screen             1302 non-null   object
#  5   CPU                1302 non-null   object
#  6   RAM                1302 non-null   object
#  7    Storage           1302 non-null   object
#  8   GPU                1302 non-null   object
#  9   Operating System   1302 non-null   object
#  10  Weight             1302 non-null   object
#  11  Price              1302 non-null   float64
#  12  Screen_resolution  1302 non-null   object
#  13  Display Type       365 non-null    object
#  14  Touchscreen        1302 non-null   float64
# dtypes: float64(3), object(12)
# ...

# %%
data = data.drop("Screen",axis = 1)

# %%
data.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                           CPU   RAM              Storage  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             GPU Operating System  Weight        Price  \
# 0  Intel Iris Plus Graphics 640            macOS  1.37kg  11912523.48
# 1        Intel HD Graphics 6000            macOS  1.34kg   7993374.48
# 2         Intel HD Graphics 620            No OS  1.86kg   5112900.00
# ...

# %%
Display_Type_counts = data["CPU"].value_counts()

# Plotting
plt.figure(figsize=(15, 4))
Display_Type_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of CPU')
plt.xlabel('GPU Type')
plt.ylabel('Count')
plt.show()

# %%
def manufacturer(x):
    x['CPU_manufacturer']=x['CPU'].str.extract(r'^(\w+)')
    x['GPU_manufacturer']=x['GPU'].str.extract(r'^(\w+)')
    return x

# %%
data=manufacturer(data)

# %%
data.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                           CPU   RAM              Storage  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             GPU Operating System  Weight        Price  \
# 0  Intel Iris Plus Graphics 640            macOS  1.37kg  11912523.48
# 1        Intel HD Graphics 6000            macOS  1.34kg   7993374.48
# 2         Intel HD Graphics 620            No OS  1.86kg   5112900.00
# ...

# %%
data['freq']=data['CPU'].str.extract(r'(\d+(?:\.\d+)?GHz)')

# %%
data['freq']=data['freq'].str.replace('GHz','')
data['freq']=data['freq'].astype(float)

# %%
data['CPU']=data['CPU'].str.replace(r'(\d+(?:\.\d+)?GHz)','',regex=True)

# %%
data.tail()
# Out:
#      Manufacturer                           Model Name            Category  \
# 1297       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1298       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1299       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1300           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1301         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       Screen Size                             CPU   RAM             Storage  \
# 1297         14.0            Intel Core i7 6500U    4GB           128GB SSD
# 1298         13.3            Intel Core i7 6500U   16GB           512GB SSD
# 1299         14.0  Intel Celeron Dual Core N3050    2GB  64GB Flash Storage
# 1300         15.6            Intel Core i7 6500U    6GB             1TB HDD
# 1301         15.6  Intel Celeron Dual Core N3050    4GB           500GB HDD
#
# ...

# %% [markdown]
# ### RAM

# %%
data['RAM_GB']= data['RAM'].str.extract(r'(\d+\.?\d*)').astype(float)

# %%
data.head(10)
# Out:
#   Manufacturer       Model Name   Category  Screen Size                   CPU  \
# 0        Apple      MacBook Pro  Ultrabook         13.3        Intel Core i5
# 1        Apple      Macbook Air  Ultrabook         13.3        Intel Core i5
# 2           HP           250 G6   Notebook         15.6  Intel Core i5 7200U
# 3        Apple      MacBook Pro  Ultrabook         15.4        Intel Core i7
# 4        Apple      MacBook Pro  Ultrabook         13.3        Intel Core i5
# 5         Acer         Aspire 3   Notebook         15.6   AMD A9-Series 9420
# 6        Apple      MacBook Pro  Ultrabook         15.4        Intel Core i7
# 7        Apple      Macbook Air  Ultrabook         13.3        Intel Core i5
# 8         Asus  ZenBook UX430UN  Ultrabook         14.0  Intel Core i7 8550U
# 9         Acer          Swift 3  Ultrabook         14.0  Intel Core i5 8250U
#
#     RAM              Storage                           GPU Operating System  \
# ...

# %%
plt.subplots(figsize=(10,6))
sns.countplot(x='RAM_GB',data=data)
plt.show()

# %% [markdown]
# ### Storage

# %%
data[['Storage1','Storage2']]=data[' Storage'].str.split('+',n=1,expand=True)

# %%
data['Storage1']=data['Storage1'].str.replace('GB','')
data['Storage2']=data['Storage2'].str.replace('GB','')

# %%
data['Storage1']=data['Storage1'].str.replace('TB','000')
data['Storage2']=data['Storage2'].str.replace('TB','000')

# %%
data.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size                   CPU  \
# 0        Apple  MacBook Pro  Ultrabook         13.3        Intel Core i5
# 1        Apple  Macbook Air  Ultrabook         13.3        Intel Core i5
# 2           HP       250 G6   Notebook         15.6  Intel Core i5 7200U
# 3        Apple  MacBook Pro  Ultrabook         15.4        Intel Core i7
# 4        Apple  MacBook Pro  Ultrabook         13.3        Intel Core i5
#
#     RAM              Storage                           GPU Operating System  \
# 0   8GB            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1   8GB  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2   8GB            256GB SSD         Intel HD Graphics 620            No OS
# 3  16GB            512GB SSD            AMD Radeon Pro 455            macOS
# 4   8GB            256GB SSD  Intel Iris Plus Graphics 650            macOS
#
# ...

# %%
data['Storage1_GB'].value_counts()
# Out:
# Storage1_GB
# 256     508
# 1000    250
# 128     177
# 512     139
# 500     132
# 32       45
# 64       17
# 2000     16
# 16       10
# 1         5
# 240       1
# 8         1
# 508       1
# Name: count, dtype: int64

# %%
data[['Storage1_GB', 'Storage1_Type']]=data['Storage1'].str.extract(r'(\d+)([a-zA-Z\s]+)')

# %%
data[['Storage2_GB', 'Storage2_Type']]=data['Storage2'].str.extract(r'(\d+)([a-zA-Z\s]+)')

# %%
data['Storage2_GB'].fillna(0, inplace=True)

# %%
data['Storage2_GB']=data['Storage2_GB'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Manufacturer       1302 non-null   object
#  1   Model Name         1302 non-null   object
#  2   Category           1302 non-null   object
#  3   Screen Size        1302 non-null   float64
#  4   CPU                1302 non-null   object
#  5   RAM                1302 non-null   object
#  6    Storage           1302 non-null   object
#  7   GPU                1302 non-null   object
#  8   Operating System   1302 non-null   object
#  9   Weight             1302 non-null   object
#  10  Price              1302 non-null   float64
#  11  Screen_resolution  1302 non-null   object
#  12  Display Type       365 non-null    object
#  13  Touchscreen        1302 non-null   float64
#  14  CPU_manufacturer   1302 non-null   object
#  15  GPU_manufacturer   1302 non-null   object
# ...

# %%
type_store=data['Storage1_Type'].value_counts()

# %%
# Display_Type_counts = data["CPU"].value_counts()

# Plotting
plt.figure(figsize=(15, 4))
type_store.plot(kind='bar', color='skyblue')
plt.title('Distribution of CPU')
plt.xlabel('GPU Type')
plt.ylabel('Count')
plt.show()

# %%
data['Storage1_Type']=data['Storage1_Type'].str.strip()

# %%
data.drop([' Storage','Storage1','Storage2'],axis=1,inplace=True)

# %%
pd.set_option('display.max_columns',100)

# %%
data.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size                   CPU  \
# 0        Apple  MacBook Pro  Ultrabook         13.3        Intel Core i5
# 1        Apple  Macbook Air  Ultrabook         13.3        Intel Core i5
# 2           HP       250 G6   Notebook         15.6  Intel Core i5 7200U
# 3        Apple  MacBook Pro  Ultrabook         15.4        Intel Core i7
# 4        Apple  MacBook Pro  Ultrabook         13.3        Intel Core i5
#
#     RAM                           GPU Operating System  Weight        Price  \
# 0   8GB  Intel Iris Plus Graphics 640            macOS  1.37kg  11912523.48
# 1   8GB        Intel HD Graphics 6000            macOS  1.34kg   7993374.48
# 2   8GB         Intel HD Graphics 620            No OS  1.86kg   5112900.00
# 3  16GB            AMD Radeon Pro 455            macOS  1.83kg  22563005.40
# 4   8GB  Intel Iris Plus Graphics 650            macOS  1.37kg  16037611.20
#
# ...

# %%
data['Weight_KG']=data['Weight'].str.extract(r'(\d+\.?\d*)').astype(float)

# %%
wt=data['Weight_KG'].value_counts()

# %% [markdown]
# ## Feature Selection

# %%
data['Storage2_Type'].value_counts()
# Out:
# Storage2_Type
#  HDD       201
#  SSD         4
#  Hybrid      2
# Name: count, dtype: int64

# %%
data.drop(['RAM','Weight','Storage2_Type'],axis=1,inplace=True)

# %%
data.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size                   CPU  \
# 0        Apple  MacBook Pro  Ultrabook         13.3        Intel Core i5
# 1        Apple  Macbook Air  Ultrabook         13.3        Intel Core i5
# 2           HP       250 G6   Notebook         15.6  Intel Core i5 7200U
# 3        Apple  MacBook Pro  Ultrabook         15.4        Intel Core i7
# 4        Apple  MacBook Pro  Ultrabook         13.3        Intel Core i5
#
#                             GPU Operating System        Price  \
# 0  Intel Iris Plus Graphics 640            macOS  11912523.48
# 1        Intel HD Graphics 6000            macOS   7993374.48
# 2         Intel HD Graphics 620            No OS   5112900.00
# 3            AMD Radeon Pro 455            macOS  22563005.40
# 4  Intel Iris Plus Graphics 650            macOS  16037611.20
#
#   Screen_resolution           Display Type  Touchscreen CPU_manufacturer  \
# 0         2560x1600  IPSPanelRetinaDisplay          0.0            Intel
# ...

# %%
data['Display Type'].value_counts()
# Out:
# Display Type
# IPSPanel                 348
# IPSPanelRetinaDisplay     17
# Name: count, dtype: int64

# %%
data.drop(['Display Type'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Manufacturer       1302 non-null   object
#  1   Model Name         1302 non-null   object
#  2   Category           1302 non-null   object
#  3   Screen Size        1302 non-null   float64
#  4   CPU                1302 non-null   object
#  5   GPU                1302 non-null   object
#  6   Operating System   1302 non-null   object
#  7   Price              1302 non-null   float64
#  8   Screen_resolution  1302 non-null   object
#  9   Touchscreen        1302 non-null   int32
#  10  CPU_manufacturer   1302 non-null   object
#  11  GPU_manufacturer   1302 non-null   object
#  12  freq               1302 non-null   float64
#  13  RAM_GB             1302 non-null   float64
#  14  Storage1_GB        1302 non-null   object
#  15  Storage1_Type      1302 non-null   object
# ...

# %%
data['Touchscreen']=data['Touchscreen'].astype(int)
